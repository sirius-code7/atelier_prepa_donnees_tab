# %% [markdown]
# ### 0. Importer les bibliothèques nécessaires
#
# **Déf :**
#
# -`NumPy est une bibliothèque open-source du langage Python conçue pour le calcul scientifique et numérique. Elle permet de manipuler facilement des tableaux et des matrices de données de grande taille (en une ou plusieurs dimensions), un peu comme une super-calculatrice mathématique ultra-rapide.`
#
# -`Pandas est une bibliothèque open-source du langage Python conçue pour la manipulation et l'analyse de données. Elle permet de travailler facilement avec des données tabulaires (lignes et colonnes), un peu comme un tableau Excel ou une table SQL`
#
# -`Matplotlib est une bibliothèque open-source du langage Python conçue pour la visualisation de données. Elle permet de créer facilement des graphiques clairs et personnalisés (courbes, histogrammes, nuages de points), un peu comme un crayon et une feuille de dessin pour illustrer vos chiffres.`
#
# -`Scikit-learn est une bibliothèque open-source du langage Python conçue pour l'apprentissage automatique (machine learning). Elle permet d'entraîner facilement des modèles pour faire des prédictions ou classer des données, un peu comme une boîte à outils intelligente capable d'apprendre à partir d'exemples passés`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# #### 0.1 Printer les versions

# %%
print("Version de Numpy :", np.__version__)
print("Version de Pandas :", pd.__version__)
print("Version de Matplotlib :", plt.matplotlib.__version__)
print("Version de Seaborn :", sns.__version__)
print("Version de Scikit-learn :", sklearn.__version__)
# Out:
# Version de Numpy : 2.4.4
# Version de Pandas : 3.0.5
# Version de Matplotlib : 3.11.1
# Version de Seaborn : 0.13.2
# Version de Scikit-learn : 1.9.0

# %% [markdown]
# ### 1.1 : Chargement des données
#
# La fonction `pd.read_csv()` permet de charger un fichier CSV dans un DataFrame Pandas.
#
# Le fichier `smart_building_raw.csv` contient les données brutes provenant des capteurs des bâtiments intelligents.
#
# Les données sont importées dans un DataFrame nommé `df`, qui sera utilisé pour toute la suite de l'atelier.

# %%
import pandas as pd

df = pd.read_csv("../data/smart_building_raw.csv")

df
# Out:
#      id_mesure                 date batiment      type_batiment zone  \
# 0         1174  2025-02-13 06:00:00       B8           Entrepôt    A
# 1         1275  2025-03-10 12:00:00       B7             Bureau    D
# 2         1493  2025-05-04 00:00:00       B5  Centre commercial    B
# 3         1073  2025-01-19 00:00:00       B6         Université    D
# 4         1454  2025-04-24 06:00:00       B7             Bureau    D
# ..         ...                  ...      ...                ...  ...
# 502       1107  2025-01-27 12:00:00       B2              École    C
# 503       1271  2025-03-09 12:00:00       B3            Hôpital    B
# 504       1349  2025-03-29 00:00:00       B5  Centre commercial    B
# 505       1436  2025-04-19 18:00:00       B7             Bureau    C
# 506       1103  2025-01-26 12:00:00       B2              École    D
#
#      temperature  humidite     co2  occupation  consommation_kwh  \
# 0           23.0      40.0   851.0        26.0             138.4
# 1           28.0      69.0   538.0         0.0             170.2
# 2           19.5      52.3  1198.0        64.0             149.8
# 3           20.0      58.4  1014.0        30.0             141.6
# 4           26.8      70.5   628.0        42.0             228.3
# ..           ...       ...     ...         ...               ...
# 502         29.8      66.5   778.0        48.0             243.5
# 503         21.1      66.3  3900.0        53.0             145.8
# 504         21.6      61.9   959.0        33.0             100.2
# 505         21.2      54.5  1066.0        38.0             150.9
# 506          NaN      64.8   584.0        29.0             163.4
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 0                  Eco       Normal        Jeudi    Non
# 1                  Eco       Normal        Lundi    Non
# 2               Normal       Normal     Dimanche    Oui
# 3               Normal       Normal     Dimanche    Non
# 4               Normal       Normal        Jeudi    Non
# ..                 ...          ...          ...    ...
# 502             Normal       Normal        Lundi    Non
# 503                Eco       Alerte     Dimanche    Oui
# 504                Eco       Normal       Samedi    Non
# 505              Boost       Normal       Samedi    Oui
# 506             Normal        Panne     Dimanche    Non
#
# [507 rows x 14 columns]

# %% [markdown]
# ### 1.2 : Afficher les premières lignes
#
# La méthode `head()` permet d'afficher les premières lignes d'un DataFrame.
#
# Par défaut, elle affiche les 5 premières lignes.
#
# Cette commande permet d'avoir un premier aperçu de la structure et du contenu des données.

# %%
df.head()
# Out:
#    id_mesure                 date batiment      type_batiment zone  \
# 0       1174  2025-02-13 06:00:00       B8           Entrepôt    A
# 1       1275  2025-03-10 12:00:00       B7             Bureau    D
# 2       1493  2025-05-04 00:00:00       B5  Centre commercial    B
# 3       1073  2025-01-19 00:00:00       B6         Université    D
# 4       1454  2025-04-24 06:00:00       B7             Bureau    D
#
#    temperature  humidite     co2  occupation  consommation_kwh  \
# 0         23.0      40.0   851.0        26.0             138.4
# 1         28.0      69.0   538.0         0.0             170.2
# 2         19.5      52.3  1198.0        64.0             149.8
# 3         20.0      58.4  1014.0        30.0             141.6
# 4         26.8      70.5   628.0        42.0             228.3
#
#   mode_climatisation etat_systeme jour_semaine alerte
# 0                Eco       Normal        Jeudi    Non
# 1                Eco       Normal        Lundi    Non
# 2             Normal       Normal     Dimanche    Oui
# 3             Normal       Normal     Dimanche    Non
# 4             Normal       Normal        Jeudi    Non

# %% [markdown]
# ### 1.3 : Afficher les dernières lignes
#
# La méthode `tail()` permet d'afficher les dernières lignes d'un DataFrame.
#
# Par défaut, elle affiche les 5 dernières lignes.
#
# Cette observation permet de vérifier que le dataset est correctement chargé jusqu'à sa dernière observation.

# %%
df.tail()
# Out:
#      id_mesure                 date batiment      type_batiment zone  \
# 502       1107  2025-01-27 12:00:00       B2              École    C
# 503       1271  2025-03-09 12:00:00       B3            Hôpital    B
# 504       1349  2025-03-29 00:00:00       B5  Centre commercial    B
# 505       1436  2025-04-19 18:00:00       B7             Bureau    C
# 506       1103  2025-01-26 12:00:00       B2              École    D
#
#      temperature  humidite     co2  occupation  consommation_kwh  \
# 502         29.8      66.5   778.0        48.0             243.5
# 503         21.1      66.3  3900.0        53.0             145.8
# 504         21.6      61.9   959.0        33.0             100.2
# 505         21.2      54.5  1066.0        38.0             150.9
# 506          NaN      64.8   584.0        29.0             163.4
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 502             Normal       Normal        Lundi    Non
# 503                Eco       Alerte     Dimanche    Oui
# 504                Eco       Normal       Samedi    Non
# 505              Boost       Normal       Samedi    Oui
# 506             Normal        Panne     Dimanche    Non

# %% [markdown]
# ### 1.4 : Nombre d'observations
#
# La propriété `shape` permet d'obtenir les dimensions d'un DataFrame.
#
# Le premier élément correspond au nombre de lignes.
#
# Chaque ligne représente une observation, c'est-à-dire une mesure enregistrée par les capteurs.

# %%
df.shape[0]
# Out:
# 507

# %% [markdown]
# ### 1.5 : Nombre de variables
#
# Le deuxième élément de la propriété `shape` correspond au nombre de colonnes.
#
# Chaque colonne représente une variable du dataset.

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# ### 1.6 : Afficher les noms des variables
#
# La propriété `columns`, combinée à `select_dtypes()`, permet d'afficher les noms de toutes les colonnes numériques du DataFrame.

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['id_mesure', 'temperature', 'humidite', 'co2', 'occupation',
#        'consommation_kwh'],
#       dtype='str')

# %% [markdown]
# #### notes sur les variables numériques
#
# Les variables numériques sont les colonnes contenant des valeurs quantitatives.
#
# À l'aide de la fonction `select_dtypes()`, les variables numériques suivantes ont été identifiées :
#
# - `id_mesure`
# - `temperature`
# - `humidite`
# - `co2`
# - `occupation`
# - `consommation_kwh`
#
# La colonne `id_mesure` est numérique, mais elle correspond à un identifiant et ne sera pas considérée comme une variable quantitative pour les analyses statistiques et les corrélations.

# %% [markdown]
# ### 1.7 : Noms des variables catégorielles
#
# La propriété `.columns`, combinée à `select_dtypes()`, permet d'obtenir uniquement les noms des colonnes de type textuel (chaînes de caractères) du DataFrame.

# %%
df.select_dtypes(include="object").columns
# Out:
# C:\Users\Invite\AppData\Local\Temp\ipykernel_5236\1196084386.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").columns
# Index(['date', 'batiment', 'type_batiment', 'zone', 'mode_climatisation',
#        'etat_systeme', 'jour_semaine', 'alerte'],
#       dtype='str')

# %% [markdown]
# #### notes sur les variables catégorielles
#
# Les variables catégorielles sont les colonnes contenant des valeurs représentant des catégories ou des groupes.
#
# Les variables catégorielles identifiées sont :
#
# - `batiment`
# - `type_batiment`
# - `zone`
# - `mode_climatisation`
# - `etat_systeme`
# - `jour_semaine`
# - `alerte`
#
# La colonne `date` apparaît également parmi les variables de type `object`, mais elle semble correspondre à une variable temporelle stockée sous forme de texte. Elle sera vérifiée et convertie dans la question suivante.

# %% [markdown]
# ### 8: Identifier les dates
#
# L'objectif est d'identifier les variables contenant des dates ou des informations temporelles.
#
# La colonne `date` a été détectée précédemment comme une variable de type `object`. Elle doit donc être vérifiée et convertie en format datetime afin de pouvoir être utilisée correctement dans les analyses temporelles.

# %%
df["date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# ### 9: Identifier les identifiants
#
# Un identifiant permet de reconnaître de manière unique une observation dans un dataset.
#
# Dans les variables disponibles, `id_mesure` semble être un identifiant numérique. Il ne doit pas être considéré comme une variable quantitative pour calculer des statistiques ou des corrélations.

# %%
# Vérifier si id_mesure contient des valeurs uniques
df["id_mesure"].is_unique
# Out:
# False

# %% [markdown]
# #### notes
#
# La colonne `id_mesure` est identifiée comme une variable d'identification(id).
#
# Son rôle est de distinguer les différentes mesures. Même si elle contient des nombres, sa valeur n'a pas de signification statistique directe.
#
# Elle sera donc exclue des analyses statistiques et des matrices de corrélation.
#
# Aussi le fait qu'elle ne contient pas de valeurs uniques indique la présence de doublons

# %%
df["id_mesure"].duplicated().sum()
# Out:
# np.int64(7)

# %% [markdown]
# ### 10: Déterminer les statistiques descriptives
#
# Les statistiques descriptives permettent de résumer les principales caractéristiques des variables numériques.
#
# Les indicateurs demandés sont :
#
# - la moyenne ;
# - la médiane ;
# - le minimum ;
# - le maximum ;
# - l'écart-type ;
# - les quartiles.
#
# La variable `id_mesure` est exclue, car elle correspond à un identifiant et non à une mesure quantitative.

# %%
variables_numeriques = [
    "temperature",
    "humidite",
    "co2",
    "occupation",
    "consommation_kwh"
]

statistiques = pd.DataFrame({
    "moyenne": df[variables_numeriques].mean(),
    "mediane": df[variables_numeriques].median(),
    "minimum": df[variables_numeriques].min(),
    "maximum": df[variables_numeriques].max(),
    "ecart_type": df[variables_numeriques].std(),
    "q1": df[variables_numeriques].quantile(0.25),
    "q2": df[variables_numeriques].quantile(0.50),
    "q3": df[variables_numeriques].quantile(0.75)
})

statistiques
# Out:
#                      moyenne  mediane  minimum  maximum  ecart_type       q1  \
# temperature        24.154141    24.00    -30.0     96.0    7.418465   21.600
# humidite           57.864113    57.55    -12.0    160.0   16.026336   49.275
# co2               844.150000   787.50     89.0   6000.0  582.181386  623.750
# occupation         44.850299    46.00    -20.0    116.0   24.949139   27.000
# consommation_kwh  169.069323   169.80   -100.0    336.2   53.164294  136.875
#
#                       q2       q3
# temperature        24.00   26.000
# humidite           57.55   65.750
# co2               787.50  952.000
# occupation         46.00   61.000
# consommation_kwh  169.80  202.975

# %% [markdown]
# #### notes sur les stats descriptives
#
# - La moyenne représente la valeur moyenne des observations. = somme/ nbr
# - La médiane représente la valeur centrale lorsque les données sont classées. = milieu
# - Le minimum représente la plus petite valeur observée.
# - Le maximum représente la plus grande valeur observée.
# - L'écart-type mesure la dispersion des données autour de la moyenne.
# - Q1 correspond au premier quartile : 25 % des valeurs lui sont inférieures ou égales.
# - Q2 correspond à la médiane.
# - Q3 correspond au troisième quartile : 75 % des valeurs lui sont inférieures ou égales.

# %% [markdown]
# ### 11: Identifier les variables potentiellement problématiques
#
# Certaines variables peuvent contenir des valeurs impossibles, inhabituelles ou incohérentes.
#
# Les variables numériques suivantes nécessitent une attention particulière :
#
# - `humidite` : une humidité inférieure à 0 ou supérieure à 100 est incohérente lorsqu'elle est exprimée en pourcentage ;
# - `temperature` : des valeurs extrêmement élevées ou anormalement basses peuvent indiquer une erreur ;
# - `co2` : des valeurs négatives ou extrêmement élevées peuvent être problématiques ;
# - `consommation_kwh` : une consommation négative est incohérente ;
# - `occupation` : des valeurs négatives ou irréalistes peuvent être incorrectes.
#
# Les variables catégorielles peuvent également présenter des problèmes :
#
# - fautes d'orthographe ;
# - espaces inutiles ;
# - différences de casse ;
# - catégories incohérentes ou inattendues.
#
# La colonne `date` doit aussi être vérifiée afin d'identifier les dates invalides ou manquantes.

# %%
# Afficher les types de données et le nombre de valeurs non nulles
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_mesure           507 non-null    int64
#  1   date                507 non-null    str
#  2   batiment            507 non-null    str
#  3   type_batiment       503 non-null    str
#  4   zone                507 non-null    str
#  5   temperature         495 non-null    float64
#  6   humidite            496 non-null    float64
#  7   co2                 500 non-null    float64
#  8   occupation          501 non-null    float64
#  9   consommation_kwh    502 non-null    float64
#  10  mode_climatisation  502 non-null    str
#  11  etat_systeme        507 non-null    str
#  12  jour_semaine        502 non-null    str
#  13  alerte              507 non-null    str
# dtypes: float64(5), int64(1), str(8)
# memory usage: 55.6 KB

# %%
variables_categorielles = [
    "batiment",
    "type_batiment",
    "zone",
    "mode_climatisation",
    "etat_systeme",
    "jour_semaine",
    "alerte"
]

for colonne in variables_categorielles:
    print(f"\n{colonne} :")
    print(df[colonne].unique())
# Out:
# batiment :
# <StringArray>
# ['B8', 'B7', 'B5', 'B6', 'B3', 'B4', 'B2', 'B1']
# Length: 8, dtype: str
#
# type_batiment :
# <StringArray>
# [         'Entrepôt',            'Bureau', 'Centre commercial',
#         'Université',           'Hôpital',             'École',
#              'ÉCOLE',             'ecole',            'BUREAU',
#                  nan,             'Bureu',            'bureau',
#        ' UNIVERSITÉ',          'hôpital ', 'centre commercial',
#           ' Bureau ',          'entrepot']
# Length: 17, dtype: str
#
# zone :
# <StringArray>
# ['A', 'D', 'B', 'C']
# Length: 4, dtype: str
#
# mode_climatisation :
# <StringArray>
# ['Eco', 'Normal', 'Boost', nan, 'normal', 'BOOST', 'normale', 'Normal ']
# Length: 8, dtype: str
#
# etat_systeme :
# <StringArray>
# ['Normal', 'Alerte', 'Panne']
# Length: 3, dtype: str
#
# jour_semaine :
# <StringArray>
# ['Jeudi', 'Lundi', 'Dimanche', 'Vendredi', 'Mercredi', 'Mardi', 'Samedi', nan]
# Length: 8, dtype: str
#
# alerte :
# <StringArray>
# ['Non', 'Oui']
# Length: 2, dtype: str

# %%
variables_numeriques = [
    "temperature",
    "humidite",
    "co2",
    "occupation",
    "consommation_kwh"
]

for colonne in variables_numeriques:
    print(f"\n{colonne} :")
    print(df[colonne].unique())
# Out:
# temperature :
# [ 23.   28.   19.5  20.   26.8  24.2  25.1  72.5  24.   22.   27.4  27.
#   24.3  26.9  24.7  29.2  20.7  21.6  26.   25.9  26.7  26.1  21.1  27.7
#   26.4  16.6  25.2  27.9  23.6  19.4   nan  21.7  25.7  21.3  20.3  21.4
#   21.2  25.3  25.   23.7  28.3  23.3  31.2  21.5  22.9  22.2  29.7  23.9
#   20.5  20.1  14.5  28.6  20.4  25.8  27.8  22.6  24.1  24.9  22.1  27.5
#   27.3  14.6  23.4  16.   24.8  22.4  25.4  25.5  22.3  23.5  21.8  22.5
#   27.2  96.   21.   26.5  22.8  18.3  18.   26.6  19.   19.2  16.3  26.2
#   28.1  28.4  34.2  22.7  88.   24.4  19.9  24.6  25.6  29.6 -25.   30.5
#   19.7  24.5  32.2  23.2  23.8  16.8  29.5  23.1  19.3  20.8  18.1  30.
#   21.9  28.5  29.8  20.2  17.8  28.7  20.6  18.6  15.8  30.1  20.9  26.3
#   18.5  29.9  18.7  29.4  17.9  17.6  29.1 -30.   30.6  17.2  16.7  19.1
#   27.6  28.8  29.   31.6  17.7  29.3  27.1  12.3  19.8  18.8  15.4  30.4
#   95.2]
#
# humidite :
# [ 40.   69.   52.3  58.4  70.5  51.5  64.4  78.3  78.4   nan  49.2  61.2
#   53.1  49.3  52.8  68.6  74.8  52.   67.3  56.   56.5  56.4  57.6  38.3
#   56.9  46.6  56.3  61.3  42.3  66.3  27.6  45.   68.   74.6  57.   53.4
#   56.7  80.2  62.3  61.   31.4  75.4  40.5  72.8  59.1  58.8  58.1  40.1
#   58.5  64.9  66.1  38.5  48.3  56.8  68.9  49.8  54.6 108.   68.7  80.5
#   53.2  74.3  52.6  51.   71.2  84.9  62.1  70.6  55.3  71.9  82.2  74.7
#   79.3  43.1  75.2  42.8  74.2  54.2  53.9  52.7  67.5  63.7  50.9  39.9
#   73.8  63.9  74.4  53.7 145.   39.2  61.1  50.3  65.4  59.2  64.2  47.9
#   78.6  48.4  73.4  86.5  62.4  46.2  50.4  46.8  23.7  60.2  52.1 160.
#   47.   43.2  79.   55.   59.7  58.2  41.2  42.2  64.6  57.7  58.3  59.9
#   77.6  61.5  51.1  54.4  59.8  59.4  55.6  60.9  51.2  50.5 125.   71.8
#   44.7  54.9  57.5  49.1  43.8  61.4  77.9  46.3  54.   38.8  51.6  48.5
#   21.5  55.8  62.6  86.3  48.2  43.5  50.   62.   47.5  71.7  64.8  53.8
#   55.9  84.4  59.   56.1  69.4  30.   55.2  40.3  75.6  81.   50.7  48.9
#   25.2  35.3  66.4  38.2  62.5  61.9  47.4  80.   58.   22.6  46.7  62.9
#   78.5  44.   37.9  57.2  38.9  36.   66.2  46.1  31.7  66.   60.   32.8
#   48.8  73.6  60.1  57.3  67.1  39.5  62.2  31.8  63.3 140.   72.6  54.8
#   72.   52.5  -5.   51.7  60.6  63.2  57.9  83.8  76.4  72.9  40.7  44.6
#   66.6  71.3  38.1  55.5  54.7  77.5  48.   69.5  42.7  89.5  67.6  60.5
#   54.1  45.1 132.   64.1  43.6  65.3  58.6  -8.   44.5  46.   46.4 110.
#   65.7  36.2  68.5  45.2  57.4  68.1  72.3  67.4  77.2  49.   40.2  44.3
#  -12.   63.5  62.8  53.   61.8  42.   37.1  52.4  49.5  69.2  45.5  35.8
#   55.7  84.6  42.1  41.1  33.   30.8  34.5  66.9  61.7  31.   63.1  63.8
#   57.8  57.1  65.1  37.4  44.1  69.1  72.1  41.5  90.7  41.6  66.7  50.1
#   32.   37.7  60.3  47.3  29.9  27.2  68.8  45.9  37.8  49.9  72.5  45.4
#   62.7  66.5  65.9  50.6  65.   54.5]
#
# co2 :
# [ 851.  538. 1198. 1014.  628.  624.  747.  257.  751.  479.  877.  555.
#  1077.  594. 1051.  859.  889.  633.  574. 1205. 1364.  568.  648. 1034.
#   707.  613.  668.  843. 6000.  631. 1000.  934.  560.  728.  872.  771.
#   899. 1113.  520.  785.  760.  748.   nan  490. 5200. 1254.  356.  645.
#   531. 1031.  544. 1022. 1299. 1046. 1084.  845.  644.  497.  826.  813.
#   915.  850.  769.  758.  918.  710.  995. 1079.  297. 1056.  687.  639.
#   823.  545.  884.  487. 1030.  731.  366.  669.  680. 1175.  430.  685.
#  1071.  602.  351.  903. 1102.  795.  445.  394.  552.  876.  898. 1070.
#   717. 1091.  712.  902.  854.  407.  670.  936.  940.  346. 1005.  807.
#   448.  314.  820.  793. 1106.  874.  952.  861.  798.  492.   89.  308.
#   830.  920.  888.  941.  528.  810.  709. 1135.  564. 1066.  609.  460.
#   836.  985. 1390.  632.  467. 1028.  852.  274.  558.  496.  815. 1123.
#   894. 1138.  828.  863.  547.  393.  897.  671.  870.  702. 1035.  563.
#   666.  911.  775.  976.  679.  745.  556.  646.  573.  527.  485. 1029.
#   566.  711.  541. 1202.  654.  732.  763.  770.  969.  753. 1040.  929.
#   855.  621.  289.  822.  422.  439.  696. 1125.  653.  974.  693.  726.
#   784.  525.  847. 1146.  892.  461.  577.  895. 1282.  764.  691. 1092.
#   474. 1229. 1161.  517.  662.  868. 1194.  462. 4500. 1252.  338.  799.
#   842.  534.  718.  722.  727.  755. 1111.  235.  667.  844.  891.  651.
#   604.  768.  652.  786.  746.  438.  565.  509.  759.  818.  781.  925.
#  1277.  948.  942.  871. 1044.  983.  506.  584. 4700.  672. 1199. 5100.
#   610.  757.  498.  937.  499.  698. 1003. 1115.  981.  966.  681.  303.
#  1027.  839.  837.  965.  977.  812.  638.  953.  663. 1494.  767.  838.
#   833.  991.  160.  416.  913.  910.  950.  882.  783.  415. 1159.  779.
#   576. 1162.  488.  600.  789.  514.  744.  869.  398.  791.  551.  627.
#   540.  684.  657.  341.  994.  682.  890. 1089.  777.  468.  866.  831.
#  1011.  735.  886. 1038.  444. 1086.  241. 1108.  858.  827.  756.  359.
#   975.  661.  692.  403.  879.  834. 1064.  873.  971. 1101.  968.  262.
#  1057.  742.  634.  482. 1184.  381. 1130.  590.  443.  516. 5500.  120.
#  1067.  982.  597.  536.  926.  471.  533.  949.  750.  959.  829.  979.
#  4800.  611. 1393.  723.  432. 1300.  928. 1147. 1302.  999.  623.  714.
#   387.  996.  907. 1171.  562.  766.  505.  375. 1080. 1519. 1054.  331.
#   431.  914.  817.  729.  549.  867.  765.  778. 3900.]
#
# occupation :
# [ 26.   0.  64.  30.  42.  52. 100.  72.  55.  70.  37.  14.  22.  51.
#   21.  57.  -5.  74.  20.  41.  59.  40.  62.  93.  83.  35.  76.  25.
#   49.  18.  44.  34.  63.  54.  28.  33.  50.  43.  75.  71.  53.  27.
#   13.  36.  17.  45.  10.  66.   7.  58.   8.  61.  23.  60.  16.  32.
#   47.  78.  73.  48.  29.  88. 101.   2.  89. 115.  90.  79.  77.  68.
#   84.  98.  56.  69.  39.  11.   4.  67.  12.  38. 116.  19.  65. 103.
#    9.  15.  85.  82.  24.   1.  95. 102.   5.  92. 109.  80.  nan  31.
#   46.  -8. 108. 113. 114. -12.   6. 110.  91.  -2. -20.]
#
# consommation_kwh :
# [ 138.4  170.2  149.8  141.6  228.3  171.9  130.5  239.7   82.9  145.
#   214.4  171.3  183.6  231.   133.9  169.3  156.3  121.2  204.7  128.8
#   237.5  184.5  170.   199.2   80.   116.   208.9  186.9   82.5  144.5
#   220.9  232.7   70.1  205.9  133.4  247.5  118.1    nan  152.5  101.5
#   133.7  167.9  193.9  185.2  171.5  106.7  244.   137.4  224.2  150.4
#   172.2  136.7  187.   114.   239.5  207.1  162.5   64.8  120.1  -15.
#   144.2  224.4  179.3   45.9  276.3   47.2   84.9  188.7  157.   205.4
#   182.6  152.2  201.2  141.9  172.4  137.6  120.4  183.5   80.4  129.3
#   156.7  217.   169.9  185.   202.2  133.2  125.8  175.   122.1  233.7
#   188.2  189.1  167.5  150.5  173.5  158.4  154.6  108.1  141.5  103.9
#   244.6   69.8  175.9  231.7  200.8  247.7  234.5  142.   124.6  148.4
#   128.4  236.2  215.1  241.5  247.6  278.8   91.2  168.   218.2  223.6
#   161.9  212.6  144.1   99.1  208.8  174.3  121.4  205.3  100.7  144.8
#    40.1  129.5  280.4  107.   155.4  180.6  200.3  145.6  208.1  168.6
#   156.4  157.3  217.8   51.7  122.7  163.   -50.   126.   180.   270.3
#    94.6   65.7  123.5  196.6  229.3  101.9  157.9  221.6  100.6  194.4
#   236.   142.8  151.6  194.1  186.5  131.9  196.3  115.3  224.8  209.7
#   279.9  124.8  202.6  168.5  115.   183.1  243.3  106.5  336.2  193.6
#   176.2  205.1   84.7  154.1  198.4  162.7  -20.   117.2  240.3  154.8
#   206.3  172.7  208.2  185.6  190.1  205.6  136.5  180.7  104.3  171.2
#   150.9  230.9  166.7  128.2  129.8   59.4  143.6  158.5   92.3  106.1
#   110.1  130.3  150.3  181.8  215.6  213.2  213.9  161.   174.2   92.5
#   163.9  212.2  180.5  172.5  201.6  154.   220.6  193.2  139.9  197.3
#   171.8  323.8  262.5  169.7  144.3  178.1  148.9  249.2   88.8  226.9
#   129.4  161.5  148.6  123.4  210.7  134.6  217.5  195.2  148.3  183.8
#   117.9  142.9  213.7  144.   146.5  212.5  295.2  247.1  225.2  187.3
#   178.2  142.6  256.8  269.2  124.7  222.8  198.9  191.2  207.5  185.5
#   183.2  156.2  204.5  302.7  198.7  141.2  132.3  196.4   70.7  135.4
#   138.   123.8  201.5  182.7  124.   282.6  257.1  183.   159.8  102.9
#   173.9  135.7  195.1  195.8   83.4  256.7  155.6  201.9  108.5   93.6
#   215.2  121.8  216.4  120.7  160.8   88.2  120.2  258.3  214.1  158.3
#   131.5  135.3  233.8  121.   249.1  145.8  163.7  193.1  167.3  151.1
#   176.8   26.4  269.8  174.9   76.5  166.6  168.7  187.6  127.1  138.8
#   253.8  143.9  119.8  179.1  189.5  179.4  134.5  151.8  251.8  169.1
#   138.7  199.1  236.7  177.2  164.2   79.6  170.6  176.   177.7  145.9
#   163.2  187.1  256.2  165.1  184.3  205.5  319.5  205.8  181.5  169.6
#   154.7  226.7  227.8  237.8  132.6   93.1  179.8  164.6   96.    81.
#   104.8  242.4  149.9  223.7  164.4  198.8  223.2  255.3  176.6  228.4
#   117.7  119.3  257.2  106.4  218.3  201.   248.7  132.9  137.9  172.3
#   100.1  211.4  152.7  146.   108.4 -100.   131.8  170.8  245.1  152.1
#   203.1  184.6  196.2  213.1  198.2  197.   208.5  207.8  238.3  185.8
#   157.4  276.4  195.7  139.6  196.8  206.   159.3   49.6  153.8  136.1
#   140.7  111.   133.   225.8  155.1  192.5  247.2  166.1  173.1  158.
#   153.9  173.6  173.4  238.9  161.7  123.1  178.6  221.4  199.3  116.7
#   246.3  226.4  108.6  243.5  100.2  163.4]

# %% [markdown]
# ### 12.a : Rechercher les humidités inférieures à 0
#
# Une humidité exprimée en pourcentage ne peut pas être négative.
#
# Nous recherchons donc les observations dont la valeur de `humidite` est inférieure à `0`.

# %%
df[df["humidite"] < 0]
# Out:
#      id_mesure                 date batiment type_batiment zone  temperature  \
# 281       1126  2025-02-01 06:00:00       B2         École    D         24.8
# 335       1036  2025-01-09 18:00:00       B4        Bureau    D         21.2
# 366       1216  2025-02-23 18:00:00       B3       Hôpital    B         23.2
#
#      humidite    co2  occupation  consommation_kwh mode_climatisation  \
# 281      -5.0  759.0        57.0             225.2              Boost
# 335      -8.0  160.0        25.0             120.2             Normal
# 366     -12.0  702.0        41.0             119.8             Normal
#
#     etat_systeme jour_semaine alerte
# 281       Normal       Samedi    Non
# 335       Alerte        Jeudi    Non
# 366       Normal     Dimanche    Non

# %% [markdown]
# ### 12.b : Rechercher les humidités supérieures à 100
#
# Une humidité exprimée en pourcentage doit être comprise entre `0` et `100`.
#
# Nous recherchons donc les observations dont la valeur de `humidite` est supérieure à `100`.

# %%
df[df["humidite"] > 100]
# Out:
#      id_mesure                 date batiment      type_batiment zone  \
# 59        1246  2025-03-03 06:00:00       B5  Centre commercial    A
# 103       1016  2025-01-04 18:00:00       B6         Université    B
# 128       1156  2025-02-08 18:00:00       B1             Bureau    A
# 160       1186  2025-02-16 06:00:00       B8           Entrepôt    B
# 268       1276  2025-03-10 18:00:00       B1             Bureau    D
# 327       1066  2025-01-17 06:00:00       B2              École    C
# 342       1096  2025-01-24 18:00:00       B8           Entrepôt    A
#
#      temperature  humidite    co2  occupation  consommation_kwh  \
# 59          24.2     108.0  813.0        18.0             -15.0
# 103         26.9     145.0  670.0        28.0             175.9
# 128          NaN     160.0  941.0        37.0             149.8
# 160         24.9     125.0    NaN        18.0             123.5
# 268         26.0     140.0  633.0        25.0             148.3
# 327         25.8     132.0  646.0        14.0              93.6
# 342         20.3     110.0  783.0        55.0             121.0
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 59              Normal       Normal        Lundi    Non
# 103             Normal       Normal       Samedi    Non
# 128                Eco       Normal       Samedi    Oui
# 160             Normal       Normal     Dimanche    Non
# 268             Normal       Normal        Lundi    Non
# 327                Eco       Normal     Vendredi    Non
# 342             Normal       Normal     Vendredi    Non

# %% [markdown]
# ### 12.c : Rechercher les températures extrêmement élevées
#
# Une température très élevée peut indiquer une erreur de mesure.
#
# Le sujet ne fournit pas de seuil précis. Pour effectuer un premier contrôle, nous considérons ici qu'une température supérieure à `50 °C` mérite une vérification.

# %%
df[df["temperature"] > 50]
# Out:
#      id_mesure                 date batiment      type_batiment zone  \
# 7         1141  2025-02-05 00:00:00       B2              École    D
# 116       1181  2025-02-15 00:00:00       B6         Université    A
# 161       1061  2025-01-16 00:00:00       B5  Centre commercial    D
# 499       1021  2025-01-06 00:00:00       B2              École    A
#
#      temperature  humidite    co2  occupation  consommation_kwh  \
# 7           72.5      78.3  257.0       100.0             239.7
# 116         96.0      86.5  874.0       115.0             241.5
# 161         88.0      50.5  393.0        62.0             196.6
# 499         95.2      65.0  314.0        43.0             246.3
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 7                Boost       Alerte     Mercredi    Non
# 116             Normal       Normal       Samedi    Non
# 161             Normal       Alerte        Jeudi    Non
# 499             Normal       Normal        Lundi    Non

# %% [markdown]
# ### 12.d : Rechercher les valeurs négatives
#
# Certaines variables numériques ne peuvent pas contenir de valeurs négatives.
#
# Nous vérifions les valeurs inférieures à `0` pour les variables numériques pertinentes afin d'identifier les éventuelles incohérences.

# %%
variables_a_verifier = [
    "temperature",
    "humidite",
    "co2",
    "occupation",
    "consommation_kwh"
]

for colonne in variables_a_verifier:
    valeurs_negatives = df[df[colonne] < 0]

    print(f"\n{colonne} : {len(valeurs_negatives)} valeur(s) négative(s)")
    display(valeurs_negatives)
# Out:
# temperature : 2 valeur(s) négative(s)
#      id_mesure                 date batiment      type_batiment zone  \
# 185       1221  2025-02-25 00:00:00       B8           Entrepôt    D
# 358       1101  2025-01-26 00:00:00       B6  centre commercial    D
#
#      temperature  humidite    co2  occupation  consommation_kwh  \
# 185        -25.0      48.5  711.0        34.0             115.0
# 358        -30.0      40.2  257.0        43.0             144.1
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 185             Normal       Normal        Mardi    Non
# 358             Normal       Normal     Dimanche    Non
# humidite : 3 valeur(s) négative(s)
#      id_mesure                 date batiment type_batiment zone  temperature  \
# 281       1126  2025-02-01 06:00:00       B2         École    D         24.8
# 335       1036  2025-01-09 18:00:00       B4        Bureau    D         21.2
# 366       1216  2025-02-23 18:00:00       B3       Hôpital    B         23.2
#
#      humidite    co2  occupation  consommation_kwh mode_climatisation  \
# 281      -5.0  759.0        57.0             225.2              Boost
# 335      -8.0  160.0        25.0             120.2             Normal
# 366     -12.0  702.0        41.0             119.8             Normal
#
#     etat_systeme jour_semaine alerte
# 281       Normal       Samedi    Non
# 335       Alerte        Jeudi    Non
# 366       Normal     Dimanche    Non
# co2 : 0 valeur(s) négative(s)
# Empty DataFrame
# Columns: [id_mesure, date, batiment, type_batiment, zone, temperature, humidite, co2, occupation, consommation_kwh, mode_climatisation, etat_systeme, jour_semaine, alerte]
# Index: []
# occupation : 5 valeur(s) négative(s)
#      id_mesure                 date batiment      type_batiment zone  \
# 22        1031  2025-01-08 12:00:00       B2              École    D
# 376       1231  2025-02-27 12:00:00       B7             Bureau    D
# 430       1081  2025-01-21 00:00:00       B1             Bureau    B
# 487       1131  2025-02-02 12:00:00       B1           entrepot    A
# 494       1331  2025-03-24 12:00:00       B5  Centre commercial    B
#
#      temperature  humidite     co2  occupation  consommation_kwh  \
# 22          26.1      57.6   648.0        -5.0             170.0
# 376         19.0      35.3   680.0        -8.0             167.9
# 430         23.5      44.1   541.0       -12.0             248.7
# 487         26.3      70.6  1519.0        -2.0             173.4
# 494         22.7      54.6   979.0       -20.0             178.6
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 22                 Eco       Normal     Mercredi    Non
# 376                Eco       Alerte        Jeudi    Non
# 430              Boost       Normal        Mardi    Non
# 487             Normal        Panne     Dimanche    Oui
# 494             Normal       Alerte        Lundi    Oui
# consommation_kwh : 4 valeur(s) négative(s)
#      id_mesure                 date batiment      type_batiment zone  \
# 59        1246  2025-03-03 06:00:00       B5  Centre commercial    A
# 154       1046  2025-01-12 06:00:00       B2              École    B
# 199       1146  2025-02-06 06:00:00       B7              Bureu    C
# 441       1346  2025-03-28 06:00:00       B5  Centre commercial    D
#
#      temperature  humidite    co2  occupation  consommation_kwh  \
# 59          24.2     108.0  813.0        18.0             -15.0
# 154         21.0      59.4  894.0        33.0             -50.0
# 199         32.2      53.8  621.0       103.0             -20.0
# 441         29.0      44.1  834.0         6.0            -100.0
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 59              Normal       Normal        Lundi    Non
# 154             Normal       Normal     Dimanche    Non
# 199             Normal       Normal        Jeudi    Non
# 441                Eco       Normal     Vendredi    Non

# %% [markdown]
# ### 12.e : Rechercher les consommations négatives
#
# Une consommation énergétique ne peut pas être négative.
#
# Nous recherchons donc les observations dont `consommation_kwh` est inférieure à `0`.

# %%
df[df["consommation_kwh"] < 0]
# Out:
#      id_mesure                 date batiment      type_batiment zone  \
# 59        1246  2025-03-03 06:00:00       B5  Centre commercial    A
# 154       1046  2025-01-12 06:00:00       B2              École    B
# 199       1146  2025-02-06 06:00:00       B7              Bureu    C
# 441       1346  2025-03-28 06:00:00       B5  Centre commercial    D
#
#      temperature  humidite    co2  occupation  consommation_kwh  \
# 59          24.2     108.0  813.0        18.0             -15.0
# 154         21.0      59.4  894.0        33.0             -50.0
# 199         32.2      53.8  621.0       103.0             -20.0
# 441         29.0      44.1  834.0         6.0            -100.0
#
#     mode_climatisation etat_systeme jour_semaine alerte
# 59              Normal       Normal        Lundi    Non
# 154             Normal       Normal     Dimanche    Non
# 199             Normal       Normal        Jeudi    Non
# 441                Eco       Normal     Vendredi    Non

# %% [markdown]
# ### 12.f : Transformer les valeurs manifestement erronées en valeurs manquantes
#
# Lorsqu'une valeur est manifestement incorrecte et qu'il est impossible de retrouver sa véritable valeur, elle est transformée en valeur manquante.
#
# Nous utilisons `NaN` afin de conserver l'information indiquant qu'une donnée est absente, sans inventer une nouvelle valeur.

# %%
# Humidité : une valeur doit être comprise entre 0 et 100 %
df.loc[
    (df["humidite"] < 0) | (df["humidite"] > 100),
    "humidite"
] = np.nan

# Température : seuil de contrôle retenu précédemment
df.loc[
    df["temperature"] > 50,
    "temperature"
] = np.nan

# CO2 : une concentration ne peut pas être négative
df.loc[
    df["co2"] < 0,
    "co2"
] = np.nan

# Occupation : un nombre de personnes ne peut pas être négatif
df.loc[
    df["occupation"] < 0,
    "occupation"
] = np.nan

# Consommation énergétique : elle ne peut pas être négative
df.loc[
    df["consommation_kwh"] < 0,
    "consommation_kwh"
] = np.nan

# %%
df[[
    "temperature",
    "humidite",
    "co2",
    "occupation",
    "consommation_kwh"
]].isna().sum()
# Out:
# temperature         16
# humidite            21
# co2                  7
# occupation          11
# consommation_kwh     9
# dtype: int64

# %% [markdown]
# ### 12.g : Rechercher les catégories mal orthographiées
#
# Les variables catégorielles peuvent contenir des fautes d'orthographe, des variantes d'une même catégorie ou des catégories inattendues.
#
# Nous affichons les valeurs uniques afin de pouvoir les examiner avant toute correction.

# %%
for colonne in variables_categorielles:
    print(f"\n{colonne} :")
    print(df[colonne].value_counts(dropna=False))
# Out:
# batiment :
# batiment
# B1    94
# B5    66
# B7    65
# B2    61
# B3    58
# B4    58
# B8    53
# B6    52
# Name: count, dtype: int64
#
# type_batiment :
# type_batiment
# Bureau               210
# Centre commercial     65
# École                 59
# Hôpital               58
# Entrepôt              52
# Université            48
# NaN                    4
# BUREAU                 2
# ÉCOLE                  1
# ecole                  1
# Bureu                  1
# bureau                 1
#  UNIVERSITÉ            1
# hôpital                1
# centre commercial      1
#  Bureau                1
# entrepot               1
# Name: count, dtype: int64
#
# zone :
# zone
# B    143
# A    125
# D    124
# C    115
# Name: count, dtype: int64
#
# mode_climatisation :
# mode_climatisation
# Normal     271
# Eco        131
# Boost       96
# NaN          5
# normal       1
# BOOST        1
# normale      1
# Normal       1
# Name: count, dtype: int64
#
# etat_systeme :
# etat_systeme
# Normal    442
# Alerte     52
# Panne      13
# Name: count, dtype: int64
#
# jour_semaine :
# jour_semaine
# Vendredi    75
# Jeudi       74
# Mercredi    73
# Samedi      72
# Dimanche    70
# Lundi       69
# Mardi       69
# NaN          5
# Name: count, dtype: int64
#
# alerte :
# alerte
# Non    361
# Oui    146
# Name: count, dtype: int64

# %% [markdown]
# ### 12.h : Normaliser les catégories textuelles
#
# Les catégories textuelles peuvent contenir des espaces inutiles ou utiliser différentes casses.
#
# Nous supprimons les espaces en début et en fin de valeur avec `strip()` puis nous uniformisons la casse avec `lower()`.

# %%
for colonne in variables_categorielles:
    df[colonne] = df[colonne].str.strip().str.lower()

# %%
for colonne in variables_categorielles:
    print(f"\n{colonne} :")
    print(df[colonne].unique())
# Out:
# batiment :
# <StringArray>
# ['b8', 'b7', 'b5', 'b6', 'b3', 'b4', 'b2', 'b1']
# Length: 8, dtype: str
#
# type_batiment :
# <StringArray>
# [         'entrepôt',            'bureau', 'centre commercial',
#         'université',           'hôpital',             'école',
#              'ecole',                 nan,             'bureu',
#           'entrepot']
# Length: 10, dtype: str
#
# zone :
# <StringArray>
# ['a', 'd', 'b', 'c']
# Length: 4, dtype: str
#
# mode_climatisation :
# <StringArray>
# ['eco', 'normal', 'boost', nan, 'normale']
# Length: 5, dtype: str
#
# etat_systeme :
# <StringArray>
# ['normal', 'alerte', 'panne']
# Length: 3, dtype: str
#
# jour_semaine :
# <StringArray>
# ['jeudi', 'lundi', 'dimanche', 'vendredi', 'mercredi', 'mardi', 'samedi', nan]
# Length: 8, dtype: str
#
# alerte :
# <StringArray>
# ['non', 'oui']
# Length: 2, dtype: str

# %% [markdown]
# ### 13.a : Calculer le nombre et le pourcentage de valeurs manquantes
#
# Nous calculons pour chaque colonne :
#
# * le nombre de valeurs manquantes ;
# * le pourcentage de valeurs manquantes par rapport au nombre total d'observations.

# %%
nombre_manquants = df.isna().sum()

pourcentage_manquants = (
    df.isna().mean() * 100
)

valeurs_manquantes = pd.DataFrame({
    "nombre_manquants": nombre_manquants,
    "pourcentage_manquants": pourcentage_manquants
})

valeurs_manquantes
# Out:
#                     nombre_manquants  pourcentage_manquants
# id_mesure                          0               0.000000
# date                               0               0.000000
# batiment                           0               0.000000
# type_batiment                      4               0.788955
# zone                               0               0.000000
# temperature                       16               3.155819
# humidite                          21               4.142012
# co2                                7               1.380671
# occupation                        11               2.169625
# consommation_kwh                   9               1.775148
# mode_climatisation                 5               0.986193
# etat_systeme                       0               0.000000
# jour_semaine                       5               0.986193
# alerte                             0               0.000000

# %% [markdown]
# ### 13.b : Identifier la variable possédant le plus de valeurs manquantes
#
# Nous recherchons la colonne qui contient le plus grand nombre de valeurs manquantes.

# %%
colonne_plus_manquante = valeurs_manquantes[
    "nombre_manquants"
].idxmax()

nombre_plus_manquant = valeurs_manquantes.loc[
    colonne_plus_manquante,
    "nombre_manquants"
]

print("Variable :", colonne_plus_manquante)
print("Nombre de valeurs manquantes :", nombre_plus_manquant)
# Out:
# Variable : humidite
# Nombre de valeurs manquantes : 21
